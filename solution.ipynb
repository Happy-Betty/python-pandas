# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import seaborn as sn

# %% [markdown]
# 1.	Write a Pandas program to compare the elements of two Pandas series.
# Sample Series [4,65,436,3,9], [7,0,3,897,9]

# %%
# DATA ANALYSIS WITH PANDAS
#SERIES
# Solution
import pandas as pd
A = pd.Series([4,65,436,3,9])
B= pd.Series([7,0,3,897,9])
print("Comparing the elements of the two pandas series")
print("Is A greater than B? ")
print(A > B)
print()
print("Is A less than B? ")
print(A < B)
print()
print("Is A equal to B? ")
print(A == B)
# Out:
# Comparing the elements of the two pandas series
# Is A greater than B?
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# dtype: bool
#
# Is A less than B?
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool
#
# Is A equal to B?
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# Question 2. Write a Pandas program to add, subtract, multiply and divide two Pandas series.

# %%
#Solution

import pandas as pd
x = pd.Series([2,4,6,8,14])
y = pd.Series([1,3,5,7,9])
add = x + y
subtract = x -y
multiply = x * y
divide = x / y
print("The sum is: ")
print(add)
print()
print("The product is: ")
print(multiply)
print()
print("the difference is: ")
print(subtract)
print()
print("The division is: ")
print(divide)
# Out:
# The sum is:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# The product is:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# the difference is:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# The division is:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# 3.	Write a Pandas program to convert a dictionary to a Pandas series.
# Sample dictionary: dictionary1 = {‘Josh’: 24, ‘Sam’: 36, ‘Peace’: 19, ‘Charles’: 65, ‘Tom’: 44}

# %%
# solution
dictionary1 = {"Josh": 24, "Sam": 36, "Peace": 19, "Charles": 65, "Tom": 44}
dx=pd.Series(dictionary1)
dx
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# 4.	Write a Pandas program to convert a given series to an array.
# Sample series: [‘Love’, 800, ‘Joy’, 789.9, ‘Peace’, True]

# %%
#Solution
#convert sample series to an array
import pandas as pd
import numpy as np
Sample_series=['Love',800,'Joy',789.9,'Peace',True] 
np.array(Sample_series)
# Out:
# array(['Love', '800', 'Joy', '789.9', 'Peace', 'True'], dtype='<U32')

# %% [markdown]
# 5.	Write a Pandas program to display the most frequent value in the given series and replace everything else as ‘Other’ in the series. (Use the ‘HomeTeamGoals’ column in the dataset provided)

# %%
import pandas as pd
#program to change the order of your DataFrame columns
afcon_df= pd.read_csv('AfricaCupofNationsMatches.csv')
afcon_df
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# Question 5 cont'd
# MOst frequent and replacing with other

# %%
print("Top 2 Freq:", afcon_df.HomeTeamGoals.value_counts())
result = afcon_df.HomeTeamGoals[afcon_df.HomeTeamGoals.isin(afcon_df.HomeTeamGoals.value_counts().index[:1])] = 'Other'
print(afcon_df.HomeTeamGoals)
print(result)
# Out:
# Top 2 Freq: 1.0    205
# 2.0    147
# 0.0    128
# 3.0     90
# 4.0     37
# 5.0      9
# 6.0      2
# Name: HomeTeamGoals, dtype: int64
# 0      Other
# 1        NaN
# 2        4.0
# 3        4.0
# 4      Other
#        ...
# 617      0.0
# 618    Other
# 619      2.0
# 620      0.0
# 621      0.0
# Name: HomeTeamGoals, Length: 622, dtype: object
# Other
# C:\Users\Betty\AppData\Local\Temp\ipykernel_9860\1703265002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result = afcon_df.HomeTeamGoals[afcon_df.HomeTeamGoals.isin(afcon_df.HomeTeamGoals.value_counts().index[:1])] = 'Other'

# %% [markdown]
# GETTING FIRST 7 ROWS OF MY DATASET

# %%
# Question 1
# pandas program to read  a csv file
afcon_df= pd.read_csv('AfricaCupofNationsMatches.csv')
afcon_df
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
# getting the first seven rows
afcon_df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# selecting a subset  of ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and ‘AwayTeamGoals’ columns from my data frame

# %%
# Question 3
columns=afcon_df[["HomeTeam","AwayTeam","HomeTeamGoals","AwayTeamGoals"]]

# %%
columns
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# select the rows where Egypt appears.

# %%
# question 4
Egypt=afcon_df[(afcon_df.AwayTeam=='Egypt')|(afcon_df.HomeTeam=='Egypt')]

# %%
Egypt
# Out:
#     Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN      Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN      Egypt     Uganda            2.0            1.0
# 9   1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
# 13  1963  24-Nov-63   NaN      Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN      Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN      Egypt   Ethiopia            3.0            0.0
#
#                 Stage    SpecialWinConditions                 Stadium  \
# 3    Final Tournament                     NaN   Prince Farouk Stadium
# 5    Final Tournament                     NaN   Prince Farouk Stadium
# 7          Semifinals                     NaN  Hailé Sélassié Stadium
# ...

# %%
# Question 5
# counting the number of rows and columns
afcon_df.shape
# Out:
# (622, 12)

# %%
#Question 6
# selecting rows where the attendence is missing
afcon_df[afcon_df['Attendance'].isna()]
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %% [markdown]
# Question 7
# HomeTeamGoals between 3 and 6 inclusive

# %%
afcon=pd.read_csv('AfricaCupofNationsMatches.csv')
afcon[afcon.HomeTeamGoals.between(3,7)]
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %% [markdown]
# program to change the “AwayTeamGoals” in the 3rd row to 10

# %%
# Question 8
av = afcon_df['AwayTeamGoals']
av[2]=10
av
# Out:
# C:\Users\Betty\AppData\Local\Temp\ipykernel_9860\604971840.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   av[2]=10
# 0       2.0
# 1       NaN
# 2      10.0
# 3       0.0
# 4       0.0
#        ...
# 617     3.0
# 618     0.0
# 619     1.0
# 620     1.0
# 621     1.0
# Name: AwayTeamGoals, Length: 622, dtype: float64

# %% [markdown]
# SORTING

# %%
# question 9
# sorting
sort=afcon_df.sort_values(['HomeTeamGoals','AwayTeamGoals'],ascending=[True,False])
sort
# Out:
#      Year                      Date   Time        HomeTeam       AwayTeam  \
# 88   1974                  11-Mar-74    NaN         Congo           Egypt
# 511  2010                  28-Jan-10  20:30       Algeria           Egypt
# 575  2019  30 June 2019 (2019-06-30)  21:00      Zimbabwe        DR Congo
# 383  2002                   7-Feb-02  19:00          Mali        Cameroon
# 397  2004                   2-Feb-04  14:00  Burkina Faso           Kenya
# ..    ...                        ...    ...            ...            ...
# 46   1970                  10-Feb-70    NaN   Ivory Coast        Ethiopia
# 1    1957                  10-Feb-57    NaN      Ethiopia    South Africa
# 489  2010                  11-Jan-10  19:30         Ghana            Togo
# 490  2010                  15-Jan-10  17:00  Burkina Faso            Togo
# 493  2010                  19-Jan-10  17:00   Ivory Coast            Togo
#
#      HomeTeamGoals  AwayTeamGoals              Stage  \
# ...

# %% [markdown]
# Pandas program to get list from DataFrame column headers.

# %%
#Question 10
list(afcon_df.columns.values)
# Out:
# ['Year',
#  'Date ',
#  'Time ',
#  'HomeTeam',
#  'AwayTeam',
#  'HomeTeamGoals',
#  'AwayTeamGoals',
#  'Stage',
#  'SpecialWinConditions',
#  'Stadium',
#  'City',
#  'Attendance']

# %% [markdown]
# appending two rows to the data frame

# %%
# question 11
new_cols=pd.read_csv('AfricaCupofNationsMatches.csv')
new_cols['Total_no_of goals']=new_cols['HomeTeamGoals']+new_cols['AwayTeamGoals']
new_cols
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
new_rows=pd.DataFrame({'Year':[2012,2013],'Date':['16-Feb-57','22-May-59'],'Time':['NaN','NaN'],'HomeTeam':['cranes','amavubi'],'AwayTeam':['amavubi','cranes'],'HomeTeamGoals':[2,3],'AwayTeamGoals':[3,2],'Stage':['Group A', 'third'],'SpecialWinConditions':['NaN','NaN'],'Stadium':['nakivubo','Nambole'],'City':['kampala','kigali'],'Attendance':[200,122]})
new_rows
# Out:
#    Year       Date Time HomeTeam AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 0  2012  16-Feb-57  NaN   cranes  amavubi              2              3
# 1  2013  22-May-59  NaN  amavubi   cranes              3              2
#
#      Stage SpecialWinConditions   Stadium     City  Attendance
# 0  Group A                  NaN  nakivubo  kampala         200
# 1    third                  NaN   Nambole   kigali         122

# %%
# creating a copy of our afcon dataframe
afcon1_df=afcon_df.copy()

# %% [markdown]
# we add our new two rows to our dataframe

# %%
#question 12
new_afcon1_df=afcon_df.append(new_rows)
new_afcon1_df
# Out:
# C:\Users\Betty\AppData\Local\Temp\ipykernel_9860\3478378729.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_afcon1_df=afcon_df.append(new_rows)
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# ...

# %% [markdown]
# program to change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame

# %%
#question 13
replace=afcon_df.AwayTeam.str.replace("Uganda","china")
replace
# Out:
# 0              Egypt
# 1       South Africa
# 2           Ethiopia
# 3           Ethiopia
# 4           Ethiopia
#            ...
# 617          Tunisia
# 618          Tunisia
# 619          Nigeria
# 620          Nigeria
# 621          Algeria
# Name: AwayTeam, Length: 622, dtype: object

# %% [markdown]
# Pandas program to reset index

# %%
#question 14
index=afcon_df.reset_index()
print(index)
# Out:
#      index  Year                      Date   Time      HomeTeam  \
# 0        0  1957                  10-Feb-57    NaN       Sudan
# 1        1  1957                  10-Feb-57    NaN    Ethiopia
# 2        2  1957                  16-Feb-57    NaN       Egypt
# 3        3  1959                  22-May-59    NaN        Egypt
# 4        4  1959                  25-May-59    NaN       Sudan
# ..     ...   ...                        ...    ...          ...
# 617    617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar
# 618    618  2019  14 July 2019 (2019-07-14)  18:00     Senegal
# 619    619  2019  14 July 2019 (2019-07-14)  21:00     Algeria
# 620    620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia
# 621    621  2019  19 July 2019 (2019-07-19)  21:00     Senegal
#
#           AwayTeam  HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0            Egypt            1.0            2.0            Semifinals
# ...

# %% [markdown]
# program to check whether the ‘Stadium’ column is present in my DataFrame or not

# %%
#question 15
if 'Stadium'in afcon_df.columns:
    print( 'Stadium is available')
else:
    print("Not availabe")
# Out:
# Stadium is available

# %% [markdown]
# program to convert the datatype of the ‘AwayTeamGoals’. (int to float)

# %%
#question 16
datatype=afcon_df.AwayTeamGoals.astype((float))
datatype
# Out:
# 0       2.0
# 1       NaN
# 2      10.0
# 3       0.0
# 4       0.0
#        ...
# 617     3.0
# 618     0.0
# 619     1.0
# 620     1.0
# 621     1.0
# Name: AwayTeamGoals, Length: 622, dtype: float64

# %% [markdown]
# remove the last 10 rows from your DataFrame.

# %%
#question 17
delete=afcon_df.iloc[:-10]
delete
# Out:
#      Year                     Date   Time      HomeTeam       AwayTeam  \
# 0    1957                 10-Feb-57    NaN       Sudan           Egypt
# 1    1957                 10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                 16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                 22-May-59    NaN        Egypt       Ethiopia
# 4    1959                 25-May-59    NaN       Sudan        Ethiopia
# ..    ...                       ...    ...          ...            ...
# 607  2019  5 July 2019 (2019-07-05)  21:00      Uganda         Senegal
# 608  2019  6 July 2019 (2019-07-06)  18:00     Nigeria        Cameroon
# 609  2019  6 July 2019 (2019-07-06)  21:00       Egypt    South Africa
# 610  2019  7 July 2019 (2019-07-07)  18:00  Madagascar        DR Congo
# 611  2019  7 July 2019 (2019-07-07)  21:00     Algeria          Guinea
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# program to iterate over rows in your DataFrame

# %%
#question 18
for index,row in afcon_df.iterrows():
    print(row['HomeTeam'],row['AwayTeam'],row['HomeTeamGoals'],row['AwayTeamGoals'],row['Stage'],row['SpecialWinConditions'],row['Stadium'],row['City'],row['Attendance'])
# Out:
# Sudan   Egypt 1.0 2.0 Semifinals nan Municipal Stadium  Khartoum 30000.0
# Ethiopia   South Africa nan nan Semifinals Ethiopia  wins due to disqualification of other team nan nan nan
# Egypt   Ethiopia 4.0 10.0 Final nan Municipal Stadium  Khartoum 30000.0
# Egypt  Ethiopia 4.0 0.0 Final Tournament nan Prince Farouk Stadium  Cairo 30000.0
# Sudan   Ethiopia 1.0 0.0 Final Tournament nan Prince Farouk Stadium  Cairo 20000.0
# Egypt  Sudan 2.0 1.0 Final Tournament nan Prince Farouk Stadium  Cairo 30000.0
# Ethiopia   Tunisia 4.0 2.0 Semifinals nan Hailé Sélassié Stadium  Addis Ababa 30000.0
# Egypt  Uganda 2.0 1.0 Semifinals nan Hailé Sélassié Stadium  Addis Ababa 30000.0
# Tunisia   Uganda 3.0 0.0 Third place match nan Hailé Sélassié Stadium  Addis Ababa nan
# Ethiopia  Egypt 4.0 2.0 Final  win after extra time  Hailé Sélassié Stadium  Addis Ababa nan
# Ghana   Tunisia 1.0 1.0 Group A nan Accra Sports Stadium  Accra nan
# ...

# %% [markdown]
# program to change the order of your DataFrame columns

# %%
# changing order of the frames
# question 19

afcon_df.iloc[:, [2,3,1,0,5,7,8,2,9,11,4,5]]
# Out:
#      Time      HomeTeam                      Date   Year  HomeTeamGoals  \
# 0      NaN       Sudan                   10-Feb-57  1957            1.0
# 1      NaN    Ethiopia                   10-Feb-57  1957            NaN
# 2      NaN       Egypt                   16-Feb-57  1957            4.0
# 3      NaN        Egypt                  22-May-59  1959            4.0
# 4      NaN       Sudan                   25-May-59  1959            1.0
# ..     ...          ...                        ...   ...            ...
# 617  21:00  Madagascar   11 July 2019 (2019-07-11)  2019            0.0
# 618  18:00     Senegal   14 July 2019 (2019-07-14)  2019            1.0
# 619  21:00     Algeria   14 July 2019 (2019-07-14)  2019            2.0
# 620  21:00     Tunisia   17 July 2019 (2019-07-17)  2019            0.0
# 621  21:00     Senegal   19 July 2019 (2019-07-19)  2019            0.0
#
#                     Stage                               SpecialWinConditions  \
# ...

# %% [markdown]
# program to delete DataFrame row(s) whose value is 0 in the ‘HomeTeamGoals’ columns

# %%
#question 20
new_htg=afcon_df[afcon_df.HomeTeamGoals!=0]
new_htg
afcon_df.isnull()# checking for null values
afcon_df.describe()# statistical data about our dataset
afcon_df.info() # information about our dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  622 non-null    int64
#  1   Date                  622 non-null    object
#  2   Time                  333 non-null    object
#  3   HomeTeam              622 non-null    object
#  4   AwayTeam              622 non-null    object
#  5   HomeTeamGoals         618 non-null    float64
#  6   AwayTeamGoals         618 non-null    float64
#  7   Stage                 622 non-null    object
#  8   SpecialWinConditions  56 non-null     object
#  9   Stadium               618 non-null    object
#  10  City                  618 non-null    object
#  11  Attendance            522 non-null    float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 58.4+ KB
